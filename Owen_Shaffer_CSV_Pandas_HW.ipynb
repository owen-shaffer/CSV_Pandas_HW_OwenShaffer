# %%
import pandas as pd

acc_players = pd.read_csv('acc_players-2324F.csv')

acc_players.head(5)
# Out:
#   Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4 Totals  \
# 0         Rk         Player      Class        Pos          School      G
# 1          1   Amaree Abram         SO          G    Georgia Tech     10
# 2          2   Sola Adebisi         FR          F   Florida State      7
# 3          3  Prince Aligbe         SO          F  Boston College     35
# 4          4     Abe Atiyeh         SR          G  Boston College      4
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12  \
# 0         MP        TRB        AST        STL  ...         TOV          PF
# 1        108         17         11          1  ...           9          10
# 2          9          1          1          0  ...           1           1
# 3        651        119         21         15  ...          30          51
# 4          6          0          0          0  ...           1           0
#
#   Unnamed: 13 Shooting Unnamed: 15 Unnamed: 16 Unnamed: 17 Advanced  \
# ...

# %%
acc_players.columns = acc_players.iloc[0]
acc_players = acc_players[1:]

# %%
acc_players.head(5)
# Out:
# 0 Rk         Player Class Pos          School   G   MP  TRB AST STL  ... TOV  \
# 1  1   Amaree Abram    SO   G    Georgia Tech  10  108   17  11   1  ...   9
# 2  2   Sola Adebisi    FR   F   Florida State   7    9    1   1   0  ...   1
# 3  3  Prince Aligbe    SO   F  Boston College  35  651  119  21  15  ...  30
# 4  4     Abe Atiyeh    SR   G  Boston College   4    6    0   0   0  ...   1
# 5  5    Zack Austin    JR   F      Pittsburgh  33  746  137  29  32  ...  13
#
# 0  PF  PTS    FG%    2P%    3P%    FT%  PER    WS   BPM
# 1  10   34  0.262  0.318    0.2  0.615  4.1  -0.1  -6.4
# 2   1    2    0.5    0.5    NaN    NaN  3.5     0  -6.7
# 3  51  164  0.435  0.522  0.147   0.62  9.4   0.9  -1.3
# 4   0    3  0.333      0      1    NaN  1.1     0  -8.2
# 5  35  216  0.417  0.563  0.295  0.737   18   2.9   7.9
#
# [5 rows x 21 columns]

# %%
acc_players['PTS'] = pd.to_numeric(acc_players['PTS'], errors='coerce')

total_points = acc_players['PTS'].sum()
print(total_points)
# Out:
# 38411

# %%
acc_players['MP'] = pd.to_numeric(acc_players['MP'], errors='coerce')
top_player = acc_players.loc[acc_players['MP'].idxmax()]
print(top_player)
# Out:
# 0
# Rk                  136
# Player    Casey Morsell
# Class                SR
# Pos                   G
# School         NC State
# G                    41
# MP                 1333
# TRB                 114
# AST                  67
# STL                  46
# BLK                  19
# TOV                  38
# PF                   86
# PTS                 455
# FG%               0.406
# 2P%               0.478
# 3P%                0.27
# FT%               0.806
# PER                13.4
# WS                  3.2
# BPM                 2.5
# Name: 136, dtype: object

# %%
acc_players['TRB'] = pd.to_numeric(acc_players['TRB'], errors='coerce')
top_rebounders = acc_players.sort_values('TRB',ascending=False).head(5)
print(top_rebounders[['Player', 'TRB']])
# Out:
# 0             Player  TRB
# 6      Armando Bacot  380
# 179  Ian Schieffelin  340
# 91   Harrison Ingram  327
# 45    Mohamed Diarra  311
# 150    Norchad Omier  309

# %%
acc_players['MP'] = pd.to_numeric(acc_players['MP'], errors='coerce')
acc_players['AST'] = pd.to_numeric(acc_players['AST'], errors='coerce')
acc_players['BLK'] = pd.to_numeric(acc_players['BLK'], errors='coerce')

playersover500 = acc_players[acc_players['MP'].astype(int) > 500]
playersover500.head(5)
# Out:
# 0   Rk         Player Class Pos          School   G    MP  TRB  AST STL  ...  \
# 3    3  Prince Aligbe    SO   F  Boston College  35   651  119   21  15  ...
# 5    5    Zack Austin    JR   F      Pittsburgh  33   746  137   29  32  ...
# 6    6  Armando Bacot    SR   F  North Carolina  37  1123  380   56  22  ...
# 8    8  Reece Beekman    SR   G        Virginia  34  1114  124  212  68  ...
# 10  10     Chris Bell    SO   F        Syracuse  32   865   75   21  18  ...
#
# 0   TOV   PF  PTS    FG%    2P%    3P%    FT%   PER   WS   BPM
# 3    30   51  164  0.435  0.522  0.147   0.62   9.4  0.9  -1.3
# 5    13   35  216  0.417  0.563  0.295  0.737    18  2.9   7.9
# 6    60  100  538   0.54  0.544    0.4  0.781  24.6  6.1   8.9
# 8    70   43  486  0.443  0.487   0.31  0.754  23.4  4.9  10.5
# 10   26   58  384  0.434  0.459   0.42  0.842  14.9  2.2   3.3
#
# [5 rows x 21 columns]

# %%
player_with_highest_assists = playersover500.loc[playersover500['AST'].astype(int).idxmax()]
print( player_with_highest_assists['Player'])
# Out:
# Reece Beekman

# %%
top_3_assist_leaders = acc_players.sort_values('AST', ascending=False).head(3)
print(top_3_assist_leaders[['Player', 'AST']])
# Out:
# 0            Player  AST
# 8     Reece Beekman  212
# 216  Jaeden Zackery  152
# 22    Elliot Cadeau  150

# %%
top_3_shot_blockers = acc_players.sort_values('BLK', ascending=False).head(3)
print(top_3_shot_blockers[['Player', 'BLK']])
# Out:
# 0           Player  BLK
# 52       Ryan Dunn   77
# 158   Quinten Post   61
# 6    Armando Bacot   56

# %%
total_points_by_school = acc_players.groupby('School')['PTS'].sum()
print(total_points_by_school)
# Out:
# School
# Boston College    2667
# Clemson           2785
# Duke              2830
# Florida State     2526
# Georgia Tech      2272
# Louisville        2304
# Miami (FL)        2424
# NC State          3101
# North Carolina    3032
# Notre Dame        2113
# Pittsburgh        2495
# Syracuse          2442
# Virginia          2140
# Virginia Tech     2547
# Wake Forest       2733
# Name: PTS, dtype: int64

# %%
total_assists_by_school = acc_players.groupby('School')['AST'].sum()
print(total_assists_by_school)
# Out:
# School
# Boston College    509
# Clemson           533
# Duke              551
# Florida State     406
# Georgia Tech      425
# Louisville        356
# Miami (FL)        454
# NC State          536
# North Carolina    536
# Notre Dame        335
# Pittsburgh        452
# Syracuse          442
# Virginia          509
# Virginia Tech     514
# Wake Forest       429
# Name: AST, dtype: int64

# %%
top_3_schools_by_points = total_points_by_school.sort_values(ascending=False).head(3)
print(top_3_schools_by_points)
# Out:
# School
# NC State          3101
# North Carolina    3032
# Duke              2830
# Name: PTS, dtype: int64

# %%
import matplotlib.pyplot as plt

top_5_scorers = acc_players.sort_values('PTS', ascending=False).head(5)
plt.figure(figsize=(6, 6))
plt.bar(top_5_scorers['Player'], top_5_scorers['PTS'])
plt.xlabel('Player')
plt.ylabel('Total Points')
plt.title('Top 5 Players by Total Points Scored')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
acc_players['FG%'] = pd.to_numeric(acc_players['FG%'], errors='coerce')
acc_players['WS'] = pd.to_numeric(acc_players['WS'], errors='coerce')

plt.figure(figsize=(6, 6))
plt.scatter(acc_players['FG%'], acc_players['WS'])
plt.xlabel('Field Goal Percentage (FG%)')
plt.ylabel('Win Shares (WS)')
plt.title('Correlation between FG% and WS')
plt.show()

correlation = acc_players['FG%'].corr(acc_players['WS'])
print(f"Correlation coefficient: {correlation}")
# Out:
# Correlation coefficient: 0.4210663894199787
